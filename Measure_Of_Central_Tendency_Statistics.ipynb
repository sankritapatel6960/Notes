# %% [markdown]
# Measure of Central Tendency

# %% [markdown]
# Mean or Average

# %%
age = [12, 21, 23, 45, 65, 43, 56, 45, 32, 67, 54, 34]

# %%
import numpy as np
np.mean(age)
# Out:
# 41.416666666666664

# %%
weights=[54, 45, 34, 67, 54, 56, 75]

# %%
np.mean(weights)
# Out:
# 55.0

# %%
import seaborn as sns
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
np.mean(df['total_bill'])
# Out:
# 19.78594262295082

# %% [markdown]
# Median

# %%
np.median(age)
# Out:
# 44.0

# %%
np.median(weights)
# Out:
# 54.0

# %%
age = [12, 21, 23, 45, 65, 43, 56, 45, 32, 67, 54, 34,200]

# %%
np.mean(age)
# Out:
# 53.61538461538461

# %%
np.median(age)
# Out:
# 45.0

# %%
from scipy import stats

# %%
stats.mode(age)
# Out:
# ModeResult(mode=45, count=2)

# %% [markdown]
# Measure of Dispersion

# %%
ages_list = [23, 43, 23, 56, 74, 32, 68, 98, 45, 32]

# %%
import numpy as np

# %%
np.mean(ages_list)
# Out:
# 49.4

# %%
np.var(ages_list)
# Out:
# 541.64

# %%
np.std(ages_list)
# Out:
# 23.273160507331188

# %%
import seaborn as sns
sns.histplot(ages_list, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
import pandas as pd

# %%
data = [[10,12,13],[34,23,45],[32,34,21]]

# %%
df = pd.DataFrame(data, columns=["A","B","C"])

# %%
df.head()
# Out:
#     A   B   C
# 0  10  12  13
# 1  34  23  45
# 2  32  34  21

# %%
df.var()
# Out:
# A    177.333333
# B    121.000000
# C    277.333333
# dtype: float64

# %%
df.var(axis=1)
# Out:
# 0      2.333333
# 1    121.000000
# 2     49.000000
# dtype: float64

# %%
df.std()
# Out:
# A    13.316656
# B    11.000000
# C    16.653328
# dtype: float64

# %%
df.std(axis=1)
# Out:
# 0     1.527525
# 1    11.000000
# 2     7.000000
# dtype: float64

# %%
Ages = [10,12,14,18,24,26,30,35,36,37,40,41,42,43,50,51]

# %%
import matplotlib.pyplot as plt
plt.hist(Ages)
# Out:
# (array([3., 1., 0., 2., 1., 0., 3., 3., 1., 2.]),
#  array([10. , 14.1, 18.2, 22.3, 26.4, 30.5, 34.6, 38.7, 42.8, 46.9, 51. ]),
#  <BarContainer object of 10 artists>)

# %%
df = sns.load_dataset('healthexp')

# %%
df.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
#Covariance
df.cov()
# Out:
# <ipython-input-26-5d28e80e2ab9>:2: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#                          Year  Spending_USD  Life_Expectancy
# Year               201.098848  2.571883e+04        41.915454
# Spending_USD     25718.827373  4.817761e+06      4166.800912
# Life_Expectancy     41.915454  4.166801e+03        10.733902

# %%
#Pearson Correlation Coefficient
df.corr(method='pearson')
# Out:
# <ipython-input-27-e4e65a64725b>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='pearson')
#                      Year  Spending_USD  Life_Expectancy
# Year             1.000000      0.826273         0.902175
# Spending_USD     0.826273      1.000000         0.579430
# Life_Expectancy  0.902175      0.579430         1.000000

# %%
#Spearman rank Correlation
df.corr(method='spearman')
# Out:
# <ipython-input-28-fdd95694a940>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='spearman')
#                      Year  Spending_USD  Life_Expectancy
# Year             1.000000      0.931598         0.896117
# Spending_USD     0.931598      1.000000         0.747407
# Life_Expectancy  0.896117      0.747407         1.000000

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.corr()
# Out:
# <ipython-input-32-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4,5,6])
#fig, ax = plt.subplots(figsize =(10, 7))
plt.hist(x)

# Show plot
plt.show()

# %% [markdown]
# Chi Square Test with Python

# %%
import scipy.stats as stat
import numpy as np

# %%
#No. of hours student study in a weekly basis daily
expected_data = [8, 6, 7, 9, 6, 9, 7]
observed_data = [7, 8, 6, 9, 9, 6, 7]

#Chi - square Goodness of fit Test
chisquare_test_statistics, p_value = stat.chisquare(observed_data, expected_data)

# %%
chisquare_test_statistics, p_value
# Out:
# (3.4345238095238093, 0.7526596580922865)

# %%
##find the critical value
dof = len(expected_data)-1
significant_value = 0.05
critical_value = stat.chi2.ppf(1-significant_value, dof)

# %%
critical_value
# Out:
# 12.591587243743977

# %%
if chisquare_test_statistics> critical_value:
  print("REject the null Hypothesis.")
else:
  print("Accept the null Hypothesis.")
# Out:
# Accept the null Hypothesis.

# %%
import numpy as np
import pandas as pd

# %%
d = {'X':[15, 12, 8, 8, 7, 7, 7, 6,5, 3], 'Y':[10, 25, 17, 11, 13, 17, 20, 13, 9, 15]}
data = pd.DataFrame(data=d)

# %%
data
# Out:
#     X   Y
# 0  15  10
# 1  12  25
# 2   8  17
# 3   8  11
# 4   7  13
# 5   7  17
# 6   7  20
# 7   6  13
# 8   5   9
# 9   3  15

# %%
data.corr(method='pearson')
# Out:
#           X         Y
# X  1.000000  0.144998
# Y  0.144998  1.000000

# %% [markdown]
# Here are the test scores of 10 students in physics and history:
#
# Physics Scores:  15  12  8   8   7   7   7   6   5   3
#
# History Scores:  10  25  17  11  13  17  20  13  9   15
#
# Compute the slope of the line of regression obtained while treating Physics as the independent variable. Compute the answer correct to three decimal places.

# %%
X = np.array([15, 12, 8, 8, 7, 7, 7, 6,5, 3])
Y = np.array([10, 25, 17, 11, 13, 17, 20, 13, 9, 15])
x_mean = np.mean(X)
y_mean = np.mean(Y)
n = np.size(X)

Sxy = np.sum(X*Y)- n*x_mean*y_mean
Sxx = np.sum(X*X)-n*x_mean*x_mean

m = Sxy/Sxx #Slope
m
# Out:
# 0.2083333333333333

# %% [markdown]
# When a student scores 10 in Physics, what is his probable score in History? Compute the answer correct to one decimal place.

# %%
c= y_mean-m*x_mean #Intercept
c
# Out:
# 13.375

# %%
y = m*10+c
y
# Out:
# 15.458333333333332

# %% [markdown]
# The two regression lines of a bivariate distribution are:
# 4x - 5y + 33 = 0 (line of y on x) 20x - 9y - 107 = 0 (line of x on y).
# Estimate the value of x when y= 7. Compute the correct answer to one decimal place.

# %%
y = 7
val_x = (9*y+107)/20
val_x
print (round(val_x, 1))
# Out:
# 8.5

# %% [markdown]
# The two regression lines of a bivariate distribution are:
# 4x - 5y + 33 = 0 (line of y on x) 20x - 9y - 107 = 0 (line of x on y). find the variance of y when  variance of x= 3. Compute the correct answer to one decimal place.
